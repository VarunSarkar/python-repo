# %% [markdown]
# <h1>Project – Capstone Project

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %matplotlib inline

# %%
customers = pd.read_csv("customer_churn.csv")
customers
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %%
customer_5 = customers.iloc[:,4]

# %%
customer_5
# Out:
# 0        No
# 1        No
# 2        No
# 3        No
# 4        No
#        ...
# 7038    Yes
# 7039    Yes
# 7040    Yes
# 7041     No
# 7042     No
# Name: Dependents, Length: 7043, dtype: object

# %%
customer_15 = customers.iloc[:,14]

# %%
customer_15
# Out:
# 0        No
# 1        No
# 2        No
# 3        No
# 4        No
#        ...
# 7038    Yes
# 7039    Yes
# 7040     No
# 7041     No
# 7042    Yes
# Name: StreamingMovies, Length: 7043, dtype: object

# %%
senior_male_customer = customers[(customers["gender"] == "Male") & (customers["SeniorCitizen"] == 1) &(customers["PaymentMethod"] == "Electronic check")]
senior_male_customer
# Out:
#       customerID gender  SeniorCitizen Partner Dependents  tenure  \
# 20    8779-QRDMV   Male              1      No         No       1
# 55    1658-BYGOY   Male              1      No         No      18
# 57    5067-XJQFU   Male              1     Yes        Yes      66
# 78    0191-ZHSKZ   Male              1      No         No      30
# 91    2424-WVHPL   Male              1      No         No       1
# ...          ...    ...            ...     ...        ...     ...
# 6837  6229-LSCKB   Male              1      No         No       6
# 6894  1400-MMYXY   Male              1     Yes         No       3
# 6914  7142-HVGBG   Male              1     Yes         No      43
# 6967  8739-WWKDU   Male              1      No         No      25
# 7032  6894-LFHLY   Male              1      No         No       1
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 20             No  No phone service             DSL             No  ...
# ...

# %%
customer_tenure70 = customers[(customers['tenure']>70) | (customers['MonthlyCharges']>100)]
customer_tenure70
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 8     7892-POOKP  Female              0     Yes         No      28
# 12    8091-TTVAX    Male              0     Yes         No      58
# 13    0280-XJGEX    Male              0      No         No      49
# 14    5129-JLPIS    Male              0      No         No      25
# 15    3655-SNQYZ  Female              0     Yes        Yes      69
# ...          ...     ...            ...     ...        ...     ...
# 7023  1035-IPQPU  Female              1     Yes         No      63
# 7034  0639-TSIQW  Female              0      No         No      67
# 7037  2569-WGERO  Female              0      No         No      72
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService MultipleLines InternetService       OnlineSecurity  ...  \
# 8             Yes           Yes     Fiber optic                   No  ...
# ...

# %%
customer_with_contract2_churn = customers[(customers['Contract']=='Two year') & (customers["PaymentMethod"] == "Mailed check") & (customers['Churn']=='Yes')]
customer_with_contract2_churn
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 268   6323-AYBRX    Male              0      No         No      59
# 5947  7951-QKZPL  Female              0     Yes        Yes      33
# 6680  9412-ARGBX  Female              0      No        Yes      48
#
#      PhoneService MultipleLines InternetService       OnlineSecurity  ...  \
# 268           Yes            No              No  No internet service  ...
# 5947          Yes           Yes              No  No internet service  ...
# 6680          Yes            No     Fiber optic                   No  ...
#
#          DeviceProtection          TechSupport          StreamingTV  \
# 268   No internet service  No internet service  No internet service
# 5947  No internet service  No internet service  No internet service
# 6680                  Yes                  Yes                  Yes
#
#           StreamingMovies  Contract PaperlessBilling PaymentMethod  \
# ...

# %%
customer_churn_sample = customers.sample(n=333)

# %%
customer_churn_sample
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 1128  0098-BOWSO    Male              0      No         No      27
# 3511  3785-KTYSH    Male              0      No         No      53
# 4884  2359-KLTEK  Female              0     Yes        Yes      41
# 957   8388-FYNPZ    Male              0      No         No       4
# 5950  2862-PFNIK    Male              0      No        Yes       1
# ...          ...     ...            ...     ...        ...     ...
# 2284  8963-JLGJT    Male              0      No        Yes       3
# 3993  9769-TSBZE  Female              0      No        Yes      70
# 2342  1552-AAGRX  Female              0      No         No      30
# 4337  2674-MLXMN  Female              1      No         No      71
# 1283  4389-UEFCZ  Female              0     Yes         No      72
#
#      PhoneService     MultipleLines InternetService       OnlineSecurity  ...  \
# 1128          Yes                No              No  No internet service  ...
# ...

# %%
customers['Churn'].value_counts()
# Out:
# No     5174
# Yes    1869
# Name: Churn, dtype: int64

# %%
plt.bar(customers['InternetService'].value_counts().keys().tolist(), customers['InternetService'].value_counts().tolist(), color='orange')
plt.xlabel('Categories of Internet Service')
plt.ylabel('Count')
plt.title('Distribution of Internet Service')
plt.show()

# %%
plt.hist(customers['tenure'], bins=30,color='green')
plt.title('Distribution of Tenure')
plt.show()

# %%
plt.scatter(customers['tenure'], customers['MonthlyCharges'])
plt.xlabel('Tenure')
plt.ylabel('Monthly Charges')
plt.title('Monthly charges VS Tenure')
plt.show()

# %%
customers.boxplot(column=['tenure'],by=['Contract'])
# Out:
# <AxesSubplot:title={'center':'tenure'}, xlabel='[Contract]'>

# %%
X = customers[['tenure']]
y = customers[['MonthlyCharges']]

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.30,random_state=0)

# %%
linReg = LinearRegression()

linReg.fit(X_train, y_train)

test_pred = linReg.predict(X_test)

# %%
np.sqrt(mean_squared_error(y_test,test_pred))
# Out:
# 29.394584027273893

# %%
X = customers[['MonthlyCharges']]
y = customers[['Churn']]

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.35,random_state=0)

# %%
from sklearn.linear_model import LogisticRegression

logRegModel = LogisticRegression()

logRegModel.fit(X_train, y_train)
# Out:
# C:\Users\Varun\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# LogisticRegression()

# %%
test_pred = logRegModel.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix, accuracy_score

print(confusion_matrix(y_test, test_pred))
print(accuracy_score(y_test, test_pred))
# Out:
# [[1815    0]
#  [ 651    0]]
# 0.7360097323600974

# %%
X = customers[['MonthlyCharges','tenure']]
y = customers[['Churn']]

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2,random_state=0)

# %%
from sklearn.linear_model import LogisticRegression

logRegModel = LogisticRegression()

logRegModel.fit(X_train, y_train)
# Out:
# C:\Users\Varun\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# LogisticRegression()

# %%
test_pred = logRegModel.predict(X_test)

# %%
print(confusion_matrix(y_test, test_pred))
print(accuracy_score(y_test, test_pred))
# Out:
# [[934 107]
#  [212 156]]
# 0.7735982966643009

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
X = customers[['tenure']]
y = customers[['Churn']]

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2,random_state=0)

# %%
DtreeModel = DecisionTreeClassifier()

DtreeModel.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
test_pred = DtreeModel.predict(X_test)

# %%
confusion_matrix(y_test, test_pred)
# Out:
# array([[965,  76],
#        [281,  87]], dtype=int64)

# %%
accuracy_score(y_test, test_pred)
# Out:
# 0.7466288147622427

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
ranForestModel = RandomForestClassifier()

# %%
ranForestModel.fit(X_train, y_train)

test_pred = ranForestModel.predict(X_test)
# Out:
# <ipython-input-41-784e65f93509>:1: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   ranForestModel.fit(X_train, y_train)

# %%
confusion_matrix(y_test, test_pred)
# Out:
# array([[965,  76],
#        [281,  87]], dtype=int64)

# %%
accuracy_score(y_test, test_pred)
# Out:
# 0.7466288147622427
